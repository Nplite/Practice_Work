# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('betsdata_a2.csv')

# %%
df.shape
# Out:
# (983042, 26)

# %%
df
# Out:
#         BET_DATE  PLAYER_ID     PRODUCT CHANNEL  PLATFORM GAME_CATEGORY  \
# 0       11/04/22   13567011  SPORTSBOOK  MOBILE       NaN          LIVE
# 1       11/04/22   11472902  SPORTSBOOK  MOBILE       NaN          LIVE
# 2       11/04/22   14396942  SPORTSBOOK  MOBILE       NaN          LIVE
# 3       11/04/22  148063171  SPORTSBOOK     WEB       NaN          LIVE
# 4       11/04/22   12581903  SPORTSBOOK  MOBILE       NaN          LIVE
# ...          ...        ...         ...     ...       ...           ...
# 983037  10/04/22   11430549  SPORTSBOOK     WEB       NaN     PRE MATCH
# 983038  10/04/22   11430549  SPORTSBOOK     WEB       NaN     PRE MATCH
# 983039  10/04/22   11016063  SPORTSBOOK  MOBILE       NaN          LIVE
# 983040  10/04/22   13659322  SPORTSBOOK  MOBILE       NaN          LIVE
# 983041  10/04/22   14342149  SPORTSBOOK     WEB       NaN     PRE MATCH
#
#        GAME_NAME  BET_COUNT BET_STATUS PRODUCT_EXPERIENCE  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# BET_DATE                   0
# PLAYER_ID                  0
# PRODUCT                    0
# CHANNEL                    0
# PLATFORM              983042
# GAME_CATEGORY              0
# GAME_NAME                  0
# BET_COUNT                  0
# BET_STATUS                 0
# PRODUCT_EXPERIENCE         0
# CASH_BET_AMOUNT            0
# CASH_WIN_AMOUNT            0
# CASH_MARGIN                0
# BONUS_BET_AMOUNT           0
# BONUS_WIN_AMOUNT           0
# BONUS_MARGIN               0
# PRODUCT_VARIANT            0
# EVENT                 400609
# EVENT_GROUP           400609
# MARKET_TYPE           400609
# MARKET                400609
# SUB_MARKET            400609
# SELECTION             400609
# PRICE                 400609
# CURRENCY_ID                0
# BONUS_COST                 0
# dtype: int64

# %%
df['EVENT'] = df.fillna(df['EVENT'].mode())

# %%
df['EVENT_GROUP'] = df.fillna(df['EVENT_GROUP'].mode())

# %%
df['MARKET_TYPE'] = df.fillna(df['MARKET_TYPE'].mode())

# %%
df['MARKET'] = df.fillna(df['MARKET'].mode())
df['SUB_MARKET'] = df.fillna(df['SUB_MARKET'].mode())
df['PRICE'] = df.fillna(df['PRICE'].mode())
df['SELECTION'] = df.fillna(df['SELECTION'].mode())

# %%
df.isnull().sum()
# Out:
# BET_DATE              0
# PLAYER_ID             0
# PRODUCT               0
# CHANNEL               0
# GAME_CATEGORY         0
# GAME_NAME             0
# BET_COUNT             0
# BET_STATUS            0
# PRODUCT_EXPERIENCE    0
# CASH_BET_AMOUNT       0
# CASH_WIN_AMOUNT       0
# CASH_MARGIN           0
# BONUS_BET_AMOUNT      0
# BONUS_WIN_AMOUNT      0
# BONUS_MARGIN          0
# PRODUCT_VARIANT       0
# EVENT                 0
# EVENT_GROUP           0
# MARKET_TYPE           0
# MARKET                0
# SUB_MARKET            0
# SELECTION             0
# PRICE                 0
# CURRENCY_ID           0
# BONUS_COST            0
# dtype: int64

# %%
df
# Out:
#         BET_DATE  PLAYER_ID     PRODUCT CHANNEL GAME_CATEGORY GAME_NAME  \
# 0       11/04/22   13567011  SPORTSBOOK  MOBILE          LIVE  Football
# 1       11/04/22   11472902  SPORTSBOOK  MOBILE          LIVE  Football
# 2       11/04/22   14396942  SPORTSBOOK  MOBILE          LIVE  Football
# 3       11/04/22  148063171  SPORTSBOOK     WEB          LIVE  Football
# 4       11/04/22   12581903  SPORTSBOOK  MOBILE          LIVE  Football
# ...          ...        ...         ...     ...           ...       ...
# 983037  10/04/22   11430549  SPORTSBOOK     WEB     PRE MATCH  Football
# 983038  10/04/22   11430549  SPORTSBOOK     WEB     PRE MATCH  Football
# 983039  10/04/22   11016063  SPORTSBOOK  MOBILE          LIVE  Football
# 983040  10/04/22   13659322  SPORTSBOOK  MOBILE          LIVE  Football
# 983041  10/04/22   14342149  SPORTSBOOK     WEB     PRE MATCH  Football
#
#         BET_COUNT BET_STATUS PRODUCT_EXPERIENCE  CASH_BET_AMOUNT  ...  \
# ...
