# %%
import pandas as pd

# %%
ls

# %%
pd.read_csv('sample_test.csv')

# %%
pd.read_csv('sample_test1.csv')

# %%
pd.read_csv('D:\Software\ohana-api-master\data\sample-csv\locations.csv')

# %%
pd.read_csv('D:\Software\ohana-api-master\data\sample-csv\services.csv')

# %%
df = pd.read_csv('taxonomy.csv')

# %%
type(df)

# %%
 pd.read_csv('taxonomy.csv')

# %%
pd.read_csv('taxonomy.csv', header= None)

# %%
pd.read_csv('taxonomy.csv',names=['a','b','c','d'])

# %%
pd.read_csv("taxonomy.csv", names=['a','b','c','d','e'])

# %%
pd.read_csv("taxonomy.csv", names=['a','b'])

# %%
df = pd.read_csv('sample_test1.csv')

# %%
df

# %%
df1 = pd.read_csv('sample_test1.csv',skiprows=[1,3])

# %%
df1

# %%
df  = pd.read_csv("services.csv")

# %%
df.dtypes

# %%
type(df)

# %%
df

# %%
df.head()

# %%
df.head(3)

# %%
df.tail()

# %%
df.tail(3)

# %%
df.columns

# %%
df.dtypes

# %%
df.columns

# %%
df['email']

# %%
df['keywords']

# %%
df['name']

# %%
df[['name','keywords']]

# %%
import pandas as pd

# %%
ls

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(df)
# Out:
# 1

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns

# %%
df1.head()

# %%
df1.head(3)

# %%
df1.tail()

# %%
df1.tail(3)

# %%
df1.dtypes

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1

# %%
df1.to_csv('NBA1.csv')

# %%
ls

# %%
df1.to_csv('NBA1',index= False)

# %%
pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
# Out:
# [                Player       Span  Mat Inns  NO  Runs   HS    Ave   BF  \
#  0           AB Agarkar  2006-2007    4    2   0    15   14   7.50   11
#  1             KK Ahmed  2018-2019   14    1   1     1   1*      -    1
#  2            S Aravind  2015-2015    1    -   -     -    -      -    -
#  3       Arshdeep Singh  2022-2023   23    4   4     6   2*      -    4
#  4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  160
#  ..                 ...        ...  ...  ...  ..   ...  ...    ...  ...
#  97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -    4
#  98   Washington Sundar  2017-2022   32   12   4    47  14*   5.87   33
#  99            SA Yadav  2021-2023   45   43   9  1578  117  46.41  875
#  100           UT Yadav  2012-2022    9    2   1    22  20*  22.00   21
#  101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  863
#
#           SR 100  50  0   4s  6s
#  0    136.36   0   0  0    2   0
#  1    100.00   0   0  0    0   0
# ...

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)

# %%
l[0]

# %%
l[1]

# %%
l[2]

# %%
l[0].to_csv('cric.csv', index= False)

# %%
l[1].to_csv('crics.csv')

# %%
l[2].to_csv('cricket12.csv',index=False)

# %%
d = """{"name" : "namdeo patil",
"email id" : "namdeopatil@gmai8l.com",
"tech" : ["ML","DL","CV"],
"platform" : ["ineuron","techneuron","kidneuron"]
}
"""

# %%
pd.DataFrame(d)

# %%
import json

# %%
result = json.loads(d)

# %%
result

# %%
type(result)

# %%
type(d)

# %%
pd.DataFrame(result)

# %%
pd.DataFrame(result['tech'])

# %%
result['tech']

# %%
url = "https://api.github.com/repos/pandas-dev.pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data

# %%
data1 = data.json()

# %%
data1

# %%
len(data1)

# %%
data1[0]

# %%
data1[0]['user']

# %%
data1[0]['user']['id']    # for fetching specific id

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])

# %%
data1

# %%
pd.DataFrame(data1,columns=['url','repository_url','labels_url'])

# %%
pd.DataFrame(data1,columns=['id','url','repository_url','labels_url','user'])

# %%
df2 = pd.DataFrame(data1,columns=['id','url','repository_url','labels_url','user'])

# %%
df2.to_csv('json.csv')

# %%
ls

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(3)

# %%
df.tail()

# %%
df.tail(3)

# %%
df.dtypes

# %%
df.to_csv('tatanic.csv')

# %%
ls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns

# %%
df.dtypes

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
 df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name =  df.dtypes[df.dtypes=='object'].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df

# %%
#try to add a new columns

# %%
df['ineuron']='sudh'

# %%
df

# %%
#try textract one single columns

# %%
df['Name']

# %%
# try to fetch first 15 records

# %%
df['Name'][0:15]  # just like a list slicing operation

# %%
df['Name'][0:15:2]

# %%
df["Name"][15:0:-2]    # reverse order

# %%
# whether i have null values or not check it in age columns

# %%
df["Age"].isnull()

# %%
df['Age'].isnull()==True

# %%
# try to fetch index of null value

# %%
df[df['Age'].isnull()== True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
df.isnull().sum().index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# how many places we have a null values

# %%
len(df[df['Age'].isnull()== True].index)
# Out:
# 177

# %%
# show me all record having null values

# %%
ind = df[df['Age'].isnull()== True].index

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df["Age"].isnull()

# %%
df[df["Age"].isnull()]

# %%
# try to fetch a person name having  max fare

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare']==max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
 df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
 df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()

# %%
import pandas as pd

# %%
pd.read_csv('D:\\Software\\bank.csv')

# %%
pd.read_csv('D:\\Software\\bank.csv',sep= ";")

# %%
#dataset link == https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
bank data set for practice

# %%
import pandas as pd

# %% [markdown]
# ### 1.how many male and female passenger are onboarded

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df['Sex']

# %%
df['Sex'].value_counts()   # it will show group by count operation
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex']=='male' # another method of filter operation

# %%
df[df['Sex']=='male']

# %%
len(df[df['Sex']=='male'])

# %%
 len(df[df['Sex']=='female'])

# %%
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %% [markdown]
# ### 2.how many survival we have

# %%
df

# %%
df['Survived']==1

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df[df['Survived']==1]

# %%
len(df[df['Survived']==1])

# %% [markdown]
# ### 3.how many casuality we have

# %%
df

# %%
df[df['Survived']==0]

# %%
len(df[df['Survived']==0])

# %% [markdown]
# ### 4. what is the name of the person who is eldest one

# %%
df['Age'] == df['Age'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'] == max(df['Age'])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df[df["Age"] == df["Age"].max()]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df[df["Age"] == df["Age"].max()]["Name"]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# ### 5. how many passengers we have in first,second and third class]

# %%
df

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# ### 6.how many passengers we have whose name is starting with "s"

# %%
df["Name"].str.startswith("S")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
df[df["Name"].str.startswith("S")]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 12            13         0       3
# 23            24         1       1
# 31            32         1       1
# 48            49         0       3
# ..           ...       ...     ...
# 851          852         0       3
# 862          863         1       1
# 863          864         0       3
# 880          881         1       2
# 884          885         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 48                                 Samaan, Mr. Youssef    male   NaN      2
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Name"].str.startswith("S")]['Name']
# Out:
# 10                       Sandstrom, Miss. Marguerite Rut
# 12                        Saundercock, Mr. William Henry
# 23                          Sloper, Mr. William Thompson
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 48                                   Samaan, Mr. Youssef
#                              ...
# 851                                  Svensson, Mr. Johan
# 862    Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863                    Sage, Miss. Dorothy Edith "Dolly"
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 884                               Sutehall, Mr. Henry Jr
# Name: Name, Length: 86, dtype: object

# %%
len(df[df["Name"].str.startswith("S")]['Name'])

# %% [markdown]
# ### 7. try to create a new column which is summation of "Sibsp " and "parch"

# %%
df["New"] = df['SibSp'] + df['Parch']

# %%
df.head()  # check the new column added

# %% [markdown]
# ### 8.how many persons we have bellow age of 25

# %%
df["Age"] < 25

# %%
df[df["Age"] < 25]

# %%
len(df[df["Age"] < 25])

# %% [markdown]
# ### 9. how many persons dies whose age was less than 40
#
# ### we have to apply filter operation on two columns age and survived

# %%
(df["Survived"] == 0) & (df["Age"] < 40)

# %%
df[(df["Survived"] == 0) & (df["Age"] < 40)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                   ...
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  New
# ...

# %%
len(df[(df["Survived"] == 0) & (df["Age"] < 40)])

# %% [markdown]
# ### 10. from a cabin column seperates text and numeric value

# %%
import re
replace  = re.compile("([a-zA-Z]+)")

df["string_cabin_list"] = df['Cabin'].str.extract(replace)
df["num_cabin_list"] = df['Cabin'].str.replace(replace, "")

# %%
df["string_cabin_list"]
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: string_cabin_list, Length: 891, dtype: object

# %%
df2 = pd.DataFrame(df.Cabin.str.split("([a-zA-Z]+)([^a-zA-Z]+)"))

# %%
df2
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 85, ]
# 2             NaN
# 3    [, C, 123, ]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 42, ]
# 888           NaN
# 889  [, C, 148, ]
# 890           NaN
#
# [891 rows x 1 columns]

# %%
df.head()

# %%
#dataset link == https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
bank data set for practice

# %%
pd.read_csv("D:\\Software\\bank.csv",sep=";")

# %%
df1 = pd.read_csv("D:\\Software\\bank.csv",sep=";")

# %%
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# ### 1. how many campaign available in this dataset

# %%
df1["campaign"].unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
len(df1["campaign"].unique())
# Out:
# 32

# %%
list(df1["campaign"])
# Out:
# [1,
#  1,
#  1,
#  4,
#  1,
#  2,
#  1,
#  2,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  2,
#  5,
#  1,
#  1,
#  1,
#  2,
#  3,
#  2,
#  2,
#  3,
#  2,
#  1,
#  1,
#  2,
#  2,
#  2,
#  3,
#  1,
#  6,
#  3,
#  1,
#  1,
#  1,
#  1,
#  18,
#  2,
#  2,
#  1,
#  3,
#  4,
#  2,
#  3,
#  1,
#  1,
#  1,
#  3,
#  2,
#  2,
#  1,
#  3,
#  2,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  4,
#  3,
#  2,
#  2,
#  1,
#  2,
#  5,
#  1,
#  2,
#  2,
#  6,
#  1,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  3,
#  1,
#  2,
#  5,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  2,
#  3,
#  2,
#  1,
#  3,
#  6,
#  5,
#  5,
#  2,
#  4,
#  2,
#  2,
#  1,
#  1,
#  2,
#  1,
#  4,
#  1,
#  2,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  10,
#  1,
#  1,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  9,
#  5,
#  4,
#  3,
#  2,
#  3,
#  1,
#  2,
#  1,
#  2,
#  3,
#  3,
#  1,
#  1,
#  1,
#  2,
#  3,
#  2,
#  2,
#  1,
# ...

# %%
len(set(list(df1["campaign"])))
# Out:
# 32

# %% [markdown]
# ### 2. how many users do we have with housing and personal load

# %%
(df1["housing"]=="yes") &(df1["loan"]=="yes")

# %%
df1[(df1["housing"] == "yes") &(df1["loan"] == "yes")]

# %%
len(df1[(df1["housing"] == "yes") &(df1["loan"] == "yes")])

# %% [markdown]
# ### 2. the persons having no personal and housing load

# %%
(df1["housing"]!="yes") &(df1["loan"]!="yes")

# %%
df1[(df1["housing"]!="yes") &(df1["loan"]!="yes")]

# %%
len(df1[(df1["housing"]!="yes") &(df1["loan"]!="yes")])

# %% [markdown]
# ### 4. how many persons we have whose age is 60+

# %%
 df1["age"]>60

# %%
df1[df1["age"]>60]

# %%
len(df1[df1["age"]>60])

# %% [markdown]
# ### 5.in which month we have targeted most of customer

# %%
df1['month'].value_counts()
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
# df1['month'].value_counts().max()

# %%
df1['month'].value_counts().index
# Out:
# Index(['may', 'jul', 'aug', 'jun', 'nov', 'apr', 'feb', 'jan', 'oct', 'sep',
#        'mar', 'dec'],
#       dtype='object')

# %%
df1['month'].value_counts().index[0]
# Out:
# 'may'

# %% [markdown]
# ### 6. which mode of call will giving you a more result

# %%
df1.groupby(['contact', 'y'])

# %%
df1.groupby(['contact', 'y']).count()
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
groupby = df1.groupby(['contact', 'y']).count()

# %%
groupby
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
groupby.loc['cellular']
# Out:
#       age   job  marital  education  default  balance  housing  loan   day  \
# y
# no   2480  2480     2480       2480     2480     2480     2480  2480  2480
# yes   416   416      416        416      416      416      416   416   416
#
#      month  duration  campaign  pdays  previous  poutcome
# y
# no    2480      2480      2480   2480      2480      2480
# yes    416       416       416    416       416       416

# %%
df.groupby.loc['cellular','yes'][0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10820\2630970098.py in <module>
# ----> 1 df.groupby.loc['cellular','yes'][0]
#
# AttributeError: 'function' object has no attribute 'loc'

# %%
df.groupby.loc['telephone','yes'][0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10820\1983102979.py in <module>
# ----> 1 df.groupby.loc['telephone','yes'][0]
#
# AttributeError: 'function' object has no attribute 'loc'

# %%
df.groupby.loc['unknown','yes'][0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10820\461108935.py in <module>
# ----> 1 df.groupby.loc['unknown','yes'][0]
#
# AttributeError: 'function' object has no attribute 'loc'

# %%
max(df.groupby.loc['telephone','yes'][0],df.groupby.loc['telephone','yes'][0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10820\3859803824.py in <module>
# ----> 1 max(df.groupby.loc['telephone','yes'][0],df.groupby.loc['telephone','yes'][0])
#
# AttributeError: 'function' object has no attribute 'loc'

# %% [markdown]
# ### 7. how many enterprenours do we have in this list

# %%
df1.head()

# %%
df1["job"] == "entrepreneur"

# %%
df1[df1["job"] == "entrepreneur"]

# %%
len(df1[df1["job"] == "entrepreneur"])

# %% [markdown]
# ### 8. how many customers we have having negative balance

# %%
df1.balance

# %%
df1.balance <0

# %%
df1[df1.balance <0]

# %%
len(df1[df1.balance <0])

# %% [markdown]
# ### 9. prepare the group of data based on the education level

# %%
df1.groupby('education').count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
df1['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
for i in df1['education'].unique():
    print(i)
# Out:
# primary
# secondary
# tertiary
# unknown

# %%
l = []
for i in df1['education'].unique():
    l.append(df1[df1['education'] == i])

# %%
len(l)
# Out:
# 4

# %%
l[0]           # here we extract only primary education data
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
https://codeshare.io/X8PY8Y #PRACTICE QUISTIONS FOR US

# %%
import pandas as pd

# %%
import numpy as n

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()      # it will drop it but not permanently
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace=True) # it will drop it permanently

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
 df.dropna(axis=1)         # it will drop NaN column that is a meaning of axis
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
"""axis = 0  means -row
axis = 1 means - column"""

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis = 1 , thresh = 800)     # it has drop age and cabin column

# %%
df.dropna(axis=1, how = "all")    # remember check shift and tab for every confusion
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value = "sudh")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value = df['Age'].mean())  #whenever age is nan then fill the avg of age
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
df.groupby('Survived').describe()['PassengerId'].T # .T will convert ropw into column like a transpose in matrix

# %%
df.groupby('Survived').describe()['PassengerId'].transpose()

# %%
df1  = pd.read_csv("D:\\Software\\bank.csv", sep= ";")

# %%
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
l = []
for i in df1['education'].unique():
    l.append(df1[df1['education'] == i])

# %%
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df2 = l[0]

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df3 = l[1]

# %%
df2

# %%
df3

# %%
"sudh" + "kumar" # this is a concardinatiion operation of str

# %%
pd.concat([df2,df3])

# %%
#i require only five record

# %%
df2 = df2.head()

# %%
df3 = df3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10820\2597150427.py in <module>
# ----> 1 df3 = df3.head()
#
# NameError: name 'df3' is not defined

# %%
pd.concat([df2,df3])   # this is a row wise concat operation

# %%
#i want concat in column wise operation

# %%
pd.concat([df2,df3],axis= 1)

# %%
 df2.columns

# %%
df2 = df2.head()[['age','job','education']]

# %%
df2

# %%
df3 = df3.head()[['age','job','education']]

# %%
df3

# %%
pd.concat([df2,df3],axis=1) # it will concat df2+df3

# %%
df5 = pd.concat([df2,df3],axis=1)

# %%
df5

# %%
df5['age']  #i want seperate columns of age

# %%
loc = take name
iloc = take integer

# %%
df5.iloc[: ,3]

# %%
df5.iloc[: ,[3,4]]

# %%
df5.iloc[[4,5] ,[3,4]]    
#4,5 = Row and 3,4 is columns
#iloc consider the default indexes

# %%
df5.loc[[9,10],['age']]    
# loc consider only name and specific named index

# %%
df2 # try to fetch a specific data
# Out:
#     age          job   marital education default  balance housing loan  \
# 0    30   unemployed   married   primary      no     1787      no   no
# 9    43     services   married   primary      no      -88     yes  yes
# 18   25  blue-collar    single   primary      no     -221     yes   no
# 26   55  blue-collar   married   primary      no      627     yes   no
# 36   78      retired  divorced   primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# 9    cellular   17   apr       313         1    147         2  failure   no
# 18    unknown   23   may       250         1     -1         0  unknown   no
# 26    unknown    5   may       247         1     -1         0  unknown   no
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
df2.loc[[9,18],['job','education']]
# Out:
#             job education
# 9      services   primary
# 18  blue-collar   primary

# %%
#dont used loc just used iloc

# %%
df2.iloc[[1,2],[1,2]]      # iloc akways consider default indexes

# %%
df2.loc[[9,18],['age','education']]

# %%
df2.iloc[[1,2],[0,2]]

# %%
df2

# %%
df3

# %%
#MERGE OPERATION

# %%
pd.merge(df2,df3)

# %%
pd.merge(df2,df3,on = 'age') # it will merge the same result on both df2 and df3 == 43
#it will consider comman in bw these two table

# %%
pd.merge(df2,df3,on = 'age',how = 'left') # it will consider every records from left table means df2
# and intersection on othr side

# %%
df2 # compare upper and this data

# %%
pd.merge(df2,df3,on = 'age',how = 'right')

# %%
df3  # compare this and upper data the other data will be intersection data

# %%
# just like a vein diagram operation

# %%
pd.merge(df2,df3,on = 'age',how = 'inner') # inner means comman BW these two data

# %%
pd.merge(df2,df3,on = 'age', how = 'outer')   #outer means selct all data

# %%
# join operation

# %%
df2

# %%
df3

# %%
df2 = df2.set_index('age')

# %%
df2

# %%
df3 = df3.set_index('age')

# %%
df3

# %%
 df2.join(df3, how = 'inner')

# %%
df2.reset_index()

# %%
df3.reset_index()

# %%
pd.merge(df2,df3)

# %%
df2.join(df3)

# %%
import pandas as pd

# %%
pd.DataFrame({'col1': [1,2,3,4,5],
              'col2' : [45,65,41,25,35],
              'col3' : "sudhanshu kumar krish ineuron onen".split()
})
# Out:
#    col1  col2       col3
# 0     1    45  sudhanshu
# 1     2    65      kumar
# 2     3    41      krish
# 3     4    25    ineuron
# 4     5    35       onen

# %%
"sudhanshu kumar krish ineuron onen".split()
# Out:
# ['sudhanshu', 'kumar', 'krish', 'ineuron', 'onen']

# %%
df = pd.DataFrame({'col1': [1,2,3,4,5],
              'col2' : [45,65,41,25,35],
              'col3' : "sudhanshu kumar krish ineuron onen".split()
})

# %%
df
# Out:
#    col1  col2       col3
# 0     1    45  sudhanshu
# 1     2    65      kumar
# 2     3    41      krish
# 3     4    25    ineuron
# 4     5    35       onen

# %%
#add new column and add value = square of col1

# %%
df['col4'] = 1

# %%
df

# %%
df['col4'] = df['col1']**2

# %%
df

# %%
#try to create cool5 to hold the col3 first letter

# %%
df['col5'] = df['col3'].str[0]

# %%
df

# %%
#try to create col6 to hold if col5 s then remain s otherwise put z in that place

# %%
def test(a):
    return a**2

# %%
df['col4_4'] = df['col1'].apply(test)

# %%
df

# %%
def test1(a):
    if a == 's':
        return "s"
    else:
        return 'z'

# %%
df['col6'] = df['col5'].apply(test1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col5'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df

# %%
df['col_6'] = df['col5'].apply(lambda a : 's' if a == "s" else 'z')

# %%
df

# %%
#try to create a new col to hold the len of col number 3

# %%
df['col7'] = df['col3'].apply(len)

# %%
df

# %%
#create new column having log of col2

# %%
import math

# %%
df['col8'] = df['col2'].apply(math.log)

# %%
df
