# %%
import pandas as pd

# %%
  ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is DE5C-05B8
#
#  Directory of C:\Users\Nplite\Favorites
#
# 05-03-2022  20:32    <DIR>          .
# 05-03-2022  22:51    <DIR>          ..
# 05-03-2022  13:09    <DIR>          .ipynb_checkpoints
# 19-02-2022  23:01    <DIR>          __pycache__
# 08-02-2022  06:47           144,486 1.Basic, List, Tuple, Dictionary  ===1.ipynb
# 21-02-2022  12:54            79,738 2.If Else, Range, For, While.ipynb
# 22-02-2022  00:08            75,849 3. Function, Lambda,Generator.ipynb
# 22-02-2022  17:53           105,786 4.Generator, Fibonacci no, Open,Write,Read file.ipynb
# 24-02-2022  20:36            79,714 5.Exception Handling, Logging.ipynb
# 28-02-2022  01:20           117,642 6.Class.ipynb
# 05-03-2022  18:08             1,173 addresses.csv
# 23-02-2022  23:20            19,704 ADVANCE TASK INEURON.ipynb
# 05-03-2022  13:07             1,503 CASSANDRA.ipynb
# 05-03-2022  18:08             1,589 contacts.csv
# ...

# %%
pd.read_csv('sample_test.csv')
# Out:
#         Name            Emailid  Address   Pincode       Sirname
# 0  Sudhanshu       sudhashu@123  Banglore   560085         Kumar
# 1      Krish    krish@gmail.com  Banglore   879562          Naik
# 2      Sunny          sunny@987  Banglore   564235        Savita
# 3     Namdeo      namdeo@ln.com  Banglore   457821         Patil
# 4    Ineuron        ineuron@123  Banglore   125463  Intellegence
# 5     Pandas  pandas@ineuron.ai  Banglore  2458762      Tutorial

# %%
pd.read_csv('D:\INEURON\h\ohana-api-master\data\sample-csv\locations.csv')
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv('D:\INEURON\h\ohana-api-master\data\sample-csv\services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
pd.read_csv('D:\INEURON\h\ohana-api-master\data\sample-csv\programs.csv')
# Out:
#    id  organization_id           name  alternate_name
# 0   1                1  Defeat Hunger             NaN

# %%
pd.read_csv('D:\INEURON\h\ohana-api-master\data\sample-csv\contacts.csv')
# Out:
#     id  location_id  organization_id  service_id                     name  \
# 0    1          1.0              NaN         NaN            Susan Houston
# 1    2          1.0              NaN         NaN       Christina Gonzalez
# 2    3          2.0              NaN         NaN             Brenda Brown
# 3    4          3.0              NaN         NaN       Howard Lader, LCSW
# 4    5          4.0              NaN         NaN       Kimberly Pesavento
# 5    6          5.0              NaN         NaN                Joe Bloom
# 6    7          6.0              NaN         NaN              Peter Olson
# 7    8          6.0              NaN         NaN             Bart Charlow
# 8    9          7.0              NaN         NaN             Bart Charlow
# 9   10          7.0              NaN         NaN             Barbara Kalt
# 10  11          8.0              NaN         NaN  Marilyn Baker-Venturini
# 11  12          8.0              NaN         NaN       Graciela Hernandez
# ...

# %%
# uploaded all sample_csv data into favourite note

# %%
pd.read_csv('taxonomy.csv')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
pd.read_csv('mail_addresses.csv')
# Out:
#     id  location_id                            attention  \
# 0    1            1   Fair Oaks Intergenerational Center
# 1    2            2           PFS Second Career Services
# 2    3            3           PFS Senior Peer Counseling
# 3    4            4         PFS Family Visitation Center
# 4    5            5  Economic Self - Sufficiency Program
# 5    6            6                         Little House
# 6    7            7                        Rosener House
# 7    8            8       Meals on Wheels - South County
# 8    9            9                     Fair Oaks Branch
# 9   10           10                         Main Library
# 10  11           11                      Schaberg Branch
# 11  12           12                         Project Read
# 12  13           13                Redwood Shores Branch
# 13  14           14                       Salvation Army
# 14  15           15          Adult Rehabilitation Center
# ...

# %%
#inside pandas evry first row consider as a coloumb row and try to create entire table according to that

# %%
"""the entire table is called as a dataframe ,dataframe is nothing but a tabular structure"""
# Out:
# 'the entire table is called as a dataframe ,dataframe is nothing but a tabular structure'

# %%
df = pd.read_clipboard("taxonomy.csv")

# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("taxonomy.csv")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
pd.read_csv("taxonomy.csv" , header = None)  # it will remove header
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
pd.read_csv("taxonomy.csv", names = ["Namdeo","Prathamesh","Dhruva","Ashok"])
# Out:
#           Namdeo                    Prathamesh     Dhruva  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                     Ashok
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
pd.read_csv("taxonomy.csv", names = ["Namdeo","Prathamesh","Dhruva","Ashok","Nanabhau"])
# Out:
#           Namdeo                    Prathamesh     Dhruva  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                     Ashok  Nanabhau
# 0             parent_name       NaN
# 1                     NaN       NaN
# 2               Emergency       NaN
# 3               Emergency       NaN
# 4          Emergency Cash       NaN
# ..                    ...       ...
# ...

# %%
pd.read_csv("taxonomy.csv", names = ["Namdeo","Prathamesh","Dhruva","Ashok","Nanabhau","a","b","c"])
# Out:
#           Namdeo                    Prathamesh     Dhruva  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                     Ashok  Nanabhau   a   b   c
# 0             parent_name       NaN NaN NaN NaN
# 1                     NaN       NaN NaN NaN NaN
# 2               Emergency       NaN NaN NaN NaN
# 3               Emergency       NaN NaN NaN NaN
# ...

# %%
pd.read_csv("taxonomy.csv", names = ["Namdeo","Prathamesh","Dhruva"])   #first two coloumb cosider as a index colomb
# Out:
#                                    Namdeo Prathamesh                Dhruva
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
pd.read_csv("taxonomy.csv", names = ["Namdeo","Prathamesh"])# first two coloumb cosider as a index colomb
# Out:
#                                              Namdeo            Prathamesh
# taxonomy_id name                          parent_id           parent_name
# 101         Emergency                           NaN                   NaN
# 101-01      Disaster Response                   101             Emergency
# 101-02      Emergency Cash                      101             Emergency
# 101-02-01   Help Pay for Food                101-02        Emergency Cash
# ...                                             ...                   ...
# 111-01-07   Workplace Rights                 111-01  Advocacy & Legal Aid
# 111-02      Mediation                           111                 Legal
# 111-03      Notary                              111                 Legal
# 111-04      Representation                      111                 Legal
# 111-05      Translation & Interpretation        111                 Legal
#
# [291 rows x 2 columns]

# %%
pd.read_csv("sample_test.csv")
# Out:
#         Name            Emailid  Address   Pincode       Sirname
# 0  Sudhanshu       sudhashu@123  Banglore   560085         Kumar
# 1      Krish    krish@gmail.com  Banglore   879562          Naik
# 2      Sunny          sunny@987  Banglore   564235        Savita
# 3     Namdeo      namdeo@ln.com  Banglore   457821         Patil
# 4    Ineuron        ineuron@123  Banglore   125463  Intellegence
# 5     Pandas  pandas@ineuron.ai  Banglore  2458762      Tutorial

# %%
#inside notepad we arereplace comma into @ so check what happen

# %%
pd.read_csv("sample_test.csv")
# Out:
#                Name@Emailid@Address @Pincode@Sirname
# 0       Sudhanshu@sudhashu@123@Banglore@560085@Kumar
# 1         Krish@krish@gmail.com@Banglore@879562@Naik
# 2             Sunny@sunny@987@Banglore@564235@Savita
# 3         Namdeo@namdeo@ln.com@Banglore@457821@Patil
# 4   Ineuron@ineuron@123@Banglore@125463@Intellegence
# 5  Pandas@pandas@ineuron.ai@Banglore@2458762@Tuto...

# %%
pd.read_csv("sample_test.csv" , sep = '@') # for email it will cosider as a new colomb
# Out:
#                Name     Emailid  Address   Pincode       Sirname
# Sudhanshu  sudhashu         123  Banglore   560085         Kumar
# Krish         krish   gmail.com  Banglore   879562          Naik
# Sunny         sunny         987  Banglore   564235        Savita
# Namdeo       namdeo      ln.com  Banglore   457821         Patil
# Ineuron     ineuron         123  Banglore   125463  Intellegence
# Pandas       pandas  ineuron.ai  Banglore  2458762      Tutorial

# %%
pd.read_csv('sample_test.csv') # wherrever replace comma into seperator |
# Out:
#                Name|Emailid|Address |Pincode|Sirname
# 0       Sudhanshu|sudhashu@123|Banglore|560085|Kumar
# 1         Krish|krish@gmail.com|Banglore|879562|Naik
# 2             Sunny|sunny@987|Banglore|564235|Savita
# 3         Namdeo|namdeo@ln.com|Banglore|457821|Patil
# 4   Ineuron|ineuron@123|Banglore|125463|Intellegence
# 5  Pandas|pandas@ineuron.ai|Banglore|2458762|Tuto...

# %%
pd.read_csv('sample_test.csv', sep = "|")
# Out:
#         Name            Emailid  Address   Pincode       Sirname
# 0  Sudhanshu       sudhashu@123  Banglore   560085         Kumar
# 1      Krish    krish@gmail.com  Banglore   879562          Naik
# 2      Sunny          sunny@987  Banglore   564235        Savita
# 3     Namdeo      namdeo@ln.com  Banglore   457821         Patil
# 4    Ineuron        ineuron@123  Banglore   125463  Intellegence
# 5     Pandas  pandas@ineuron.ai  Banglore  2458762      Tutorial

# %%
df = pd.read_csv('sample_test.csv', sep = "|")

# %%
df
# Out:
#         Name            Emailid  Address   Pincode       Sirname
# 0  Sudhanshu       sudhashu@123  Banglore   560085         Kumar
# 1      Krish    krish@gmail.com  Banglore   879562          Naik
# 2      Sunny          sunny@987  Banglore   564235        Savita
# 3     Namdeo      namdeo@ln.com  Banglore   457821         Patil
# 4    Ineuron        ineuron@123  Banglore   125463  Intellegence
# 5     Pandas  pandas@ineuron.ai  Banglore  2458762      Tutorial

# %%
df1 = pd.read_csv('sample_test.csv' ,skiprows = [1,3])  #you dont want some rows

# %%
"""dont remember any command just shift and tab you will get anything inside pandas"""
# Out:
# 'dont remember any command just shift and tab you will get anything inside pandas'

# %%
df1
# Out:
#       Name            Emailid  Address   Pincode       Sirname
# 0    Krish    krish@gmail.com  Banglore   879562          Naik
# 1   Namdeo      namdeo@ln.com  Banglore   457821         Patil
# 2  Ineuron        ineuron@123  Banglore   125463  Intellegence
# 3   Pandas  pandas@ineuron.ai  Banglore  2458762      Tutorial

# %%
df = pd.read_csv("services.csv")

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes    # in pandas object is a str
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
#  i want a sample record

# %%
df.head()   # it will shown only first 5 record bydefault
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
 df.tail()   # it will show you last 5 record from bottom
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
#in jupitor notebook it not showing all the record, it will load whole record
#if you want to show whole record you will save this record inside file system and open it

# %%
df.columns        # df.c   and press tab
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df.dtypes             # df.d   and press tab
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.columns #I WANT SPECIFIC COLUMB FROM WHOLE DATAFRAME
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df['email']
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %%
 df['keywords']
# Out:
# 0     ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1     EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2     Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3     INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4        COMMUNITY SERVICES, Speakers, Automobile Loans
# 5     ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6     ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7     ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8     EDUCATION SERVICES, Library, Libraries, Public...
# 9     EDUCATION SERVICES, Library, Libraries, Public...
# 10    EDUCATION SERVICES, Library, Libraries, Public...
# 11    EDUCATION SERVICES, Adult, Alternative, Litera...
# 12    EDUCATION SERVICES, Library, Libraries, Public...
# 13    COMMUNITY SERVICES, Interpretation/Translation...
# 14    ALCOHOLISM SERVICES, Residential Care, DRUG AB...
# 15    COMMODITY SERVICES, Clothing/Personal Items, C...
# 16    COMMODITY SERVICES, Clothing/Personal Items, C...
# ...

# %%
df['name']
# Out:
# 0          Fair Oaks Adult Activity Center
# 1         Second Career Employment Program
# 2                   Senior Peer Counseling
# 3                 Family Visitation Center
# 4        Economic Self-Sufficiency Program
# 5     Little House Recreational Activities
# 6         Rosener House Adult Day Services
# 7           Meals on Wheels - South County
# 8                         Fair Oaks Branch
# 9                             Main Library
# 10                         Schaberg Branch
# 11                            Project Read
# 12                   Redwood Shores Branch
# 13                      Redwood City Corps
# 14             Adult Rehabilitation Center
# 15                         Sunnyvale Corps
# 16       South San Francisco Citadel Corps
# 17                           Project Smile
# 18           San Mateo Free Medical Clinic
# 19               Service with blank fields
# 20         Service for Admin Test Location
# 21                         Passport Photos
# ...

# %%
#i would like to see a data in multiple columb

# %%
a = df['name']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
"""dataframe is a combination of multiple series
series is nothing but a row and columb of data"""
# Out:
# 'dataframe is a combination of multiple series\nseries is nothing but a row and columb of data'

# %%
df['name','location_id'] # its not going to works
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'location_id')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-153c776184de> in <module>
# ...

# %%
df[['name','location_id','id']]
# Out:
#                                     name  location_id  id
# 0        Fair Oaks Adult Activity Center            1   1
# 1       Second Career Employment Program            2   2
# 2                 Senior Peer Counseling            3   3
# 3               Family Visitation Center            4   4
# 4      Economic Self-Sufficiency Program            5   5
# 5   Little House Recreational Activities            6   6
# 6       Rosener House Adult Day Services            7   7
# 7         Meals on Wheels - South County            8   8
# 8                       Fair Oaks Branch            9   9
# 9                           Main Library           10  10
# 10                       Schaberg Branch           11  11
# 11                          Project Read           12  12
# 12                 Redwood Shores Branch           13  13
# 13                    Redwood City Corps           14  14
# 14           Adult Rehabilitation Center           15  15
# ...

# %%
df1 = df[['name','location_id','id']]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['name']]
# Out:
#                                     name
# 0        Fair Oaks Adult Activity Center
# 1       Second Career Employment Program
# 2                 Senior Peer Counseling
# 3               Family Visitation Center
# 4      Economic Self-Sufficiency Program
# 5   Little House Recreational Activities
# 6       Rosener House Adult Day Services
# 7         Meals on Wheels - South County
# 8                       Fair Oaks Branch
# 9                           Main Library
# 10                       Schaberg Branch
# 11                          Project Read
# 12                 Redwood Shores Branch
# 13                    Redwood City Corps
# 14           Adult Rehabilitation Center
# 15                       Sunnyvale Corps
# 16     South San Francisco Citadel Corps
# 17                         Project Smile
# 18         San Mateo Free Medical Clinic
# 19             Service with blank fields
# 20       Service for Admin Test Location
# 21                       Passport Photos
# ...

# %%
type(df[['name']]) # check the difference
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is DE5C-05B8
#
#  Directory of C:\Users\Nplite\Favorites
#
# 05-03-2022  23:04    <DIR>          .
# 05-03-2022  22:51    <DIR>          ..
# 05-03-2022  13:09    <DIR>          .ipynb_checkpoints
# 19-02-2022  23:01    <DIR>          __pycache__
# 08-02-2022  06:47           144,486 1.Basic, List, Tuple, Dictionary  ===1.ipynb
# 21-02-2022  12:54            79,738 2.If Else, Range, For, While.ipynb
# 22-02-2022  00:08            75,849 3. Function, Lambda,Generator.ipynb
# 22-02-2022  17:53           105,786 4.Generator, Fibonacci no, Open,Write,Read file.ipynb
# 24-02-2022  20:36            79,714 5.Exception Handling, Logging.ipynb
# 28-02-2022  01:20           117,642 6.Class.ipynb
# 05-03-2022  18:08             1,173 addresses.csv
# 23-02-2022  23:20            19,704 ADVANCE TASK INEURON.ipynb
# 05-03-2022  13:07             1,503 CASSANDRA.ipynb
# 05-03-2022  18:08             1,589 contacts.csv
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx')
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
pd.read_excel("LUSID Excel - Manage Orders.xlsx", sheet_name = "Allocations") # it can be read each and evry data present inside excel sheet
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
pd.read_excel("LUSID Excel - Manage Orders.xlsx")
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df.keys()
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df = pd.ExcelFile("LUSID Excel - Manage Orders.xlsx")

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    pd.read_excel("LUSID Excel - Manage Orders.xlsx", sheet_name= i)

# %%
#if i want to read data from google link = titanic.csv github == so try to press RAW and copy RAW.github URL from github file and insert in pandas

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
"""it is important so dont be download just keep url copy it and past inside pandas"""
# Out:
# 'it is important so dont be download just keep url copy it and past inside pandas'

# %%
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/taxonomy.csv')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
#inside python project we used such kind of implimentation

# %%
27/02/2022 class pandas day2

# %%
import pandas as pd

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')  # this link copy from google
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
#dataset is not in readable formate or tabular formate

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')  # this link copy from google

# %%
type(df)
# Out:
# list

# %%
"""check how many elements are there inside a list"""
# Out:
# 'check how many elements are there inside a list'

# %%
len(df)
# Out:
# 1

# %%
df[0]   # this command for readable form
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.tail(4)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 671  170  245  135  86  17  75  115  685
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [4 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1[['Age','GS','FGA']]
# Out:
#     Age  GS  FGA
# 0    24  22  331
# 1    20   0   86
# 2    21  67  399
# 3    28   0   44
# 4    29  72  884
# ..   ..  ..  ...
# 670  26  68  968
# 671  26  48  641
# 672  26  20  327
# 673  22  45  373
# 674  25  59  619
#
# [675 rows x 3 columns]

# %%
#try to store this data for reading entire data or hidden columb

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.to_csv('NBA.csv') # created a file and save data inside NBA.csv file

# %%
ls # check NBA.csv file
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is DE5C-05B8
#
#  Directory of C:\Users\Nplite\Favorites
#
# 06-03-2022  00:35    <DIR>          .
# 05-03-2022  22:51    <DIR>          ..
# 05-03-2022  13:09    <DIR>          .ipynb_checkpoints
# 19-02-2022  23:01    <DIR>          __pycache__
# 08-02-2022  06:47           144,486 1.Basic, List, Tuple, Dictionary  ===1.ipynb
# 21-02-2022  12:54            79,738 2.If Else, Range, For, While.ipynb
# 22-02-2022  00:08            75,849 3. Function, Lambda,Generator.ipynb
# 22-02-2022  17:53           105,786 4.Generator, Fibonacci no, Open,Write,Read file.ipynb
# 24-02-2022  20:36            79,714 5.Exception Handling, Logging.ipynb
# 28-02-2022  01:20           117,642 6.Class.ipynb
# 05-03-2022  18:08             1,173 addresses.csv
# 23-02-2022  23:20            19,704 ADVANCE TASK INEURON.ipynb
# 05-03-2022  13:07             1,503 CASSANDRA.ipynb
# 05-03-2022  18:08             1,589 contacts.csv
# ...

# %%
pd.read_csv('NBA.csv')
# Out:
#      Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1      Quincy Acy  PF  24  NYK  68  22  1287  152  ...
# 1             1    2    Jordan Adams  SG  20  MEM  30   0   248   35  ...
# 2             2    3    Steven Adams   C  21  OKC  70  67  1771  217  ...
# 3             3    4     Jeff Adrien  PF  28  MIN  17   0   215   19  ...
# 4             4    5   Arron Afflalo  SG  29  TOT  78  72  2502  375  ...
# ..          ...  ...             ...  ..  ..  ...  ..  ..   ...  ...  ...
# 670         670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  ...
# 671         671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  ...
# 672         672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  ...
# 673         673  491     Cody Zeller   C  22  CHO  62  45  1487  172  ...
# 674         674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  ...
#
#       FT%  ORB  DRB  TRB  AST  STL BLK  TOV   PF   PTS
# ...

# %%
#read data inside our c drive by copying link from ls note

# %%
df1.to_csv('NBA.csv',index= False) #check NBA file incide c drive there is no index

# %%
df1.to_csv('NBA.csv', header= False) #it will remove header

# %%
pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
# Out:
# [               Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
#  0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
#  1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
#  2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
#  3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
#  4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
#  ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
#  92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
#  93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
#  94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
#  95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
#  96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#     100 50  0  4s  6s
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-e75269d816bd> in <module>
# ----> 1 len(l)
#
# NameError: name 'l' is not defined

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 3

# %%
l[0] # it will fetch all data
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# ...

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
# 2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...

# %%
l[0].to_csv('cricket.csv', index = False) # store data inside a cdrive

# %%
"""we can extract table from pdf/word documents anything you want just name it"""
# Out:
# 'we can extract table from pdf/word documents anything you want just name it'

# %%
d = """
{ "name" : "sudhanshu kumar",
"email_id" : "sudhanshu@ineuron.ai",
"tech" : ["ML","DL","NLP"],

"platform" :  ["techneuron","kidneuron","ineuron"]
}"""              #copy these dict and past in json viewer and learn

# %%
"""convert this data into tabular form or dataframe formate"""
# Out:
# 'convert this data into tabular form or dataframe formate'

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-3449b472dc69> in <module>
# ----> 1 pd.DataFrame(d)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     588         else:
#     589             if index is None or columns is None:
# --> 590                 raise ValueError("DataFrame constructor not properly called!")
#     591
#     592             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %%
import json                             # java scripted orig nating file

# %%
"""json file used in industery alot bcoz its a light wieght formate to transfer form one place to another place
json viewver will read unreadable data(dict formate) into more readable formate"""
# Out:
# 'json file used in industery alot bcoz its a light wieght formate to transfer form one place to another place\njson viewver will read unreadable data(dict formate) into more readable formate'

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'sudhanshu kumar',
#  'email_id': 'sudhanshu@ineuron.ai',
#  'tech': ['ML', 'DL', 'NLP'],
#  'platform': ['techneuron', 'kidneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
type(d)
# Out:
# str

# %%
pd.DataFrame(result)
# Out:
#               name              email_id tech    platform
# 0  sudhanshu kumar  sudhanshu@ineuron.ai   ML  techneuron
# 1  sudhanshu kumar  sudhanshu@ineuron.ai   DL   kidneuron
# 2  sudhanshu kumar  sudhanshu@ineuron.ai  NLP     ineuron

# %%
pd.DataFrame(result['name'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-eb30885eb967> in <module>
# ----> 1 pd.DataFrame(result['name'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     588         else:
#     589             if index is None or columns is None:
# --> 590                 raise ValueError("DataFrame constructor not properly called!")
#     591
#     592             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame(result['tech']) #bcoz tech is list
# Out:
#      0
# 0   ML
# 1   DL
# 2  NLP

# %%
result['tech']
# Out:
# ['ML', 'DL', 'NLP']

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# ...

# %%
#try to extract data dictionary

# %%
d1 = d["data"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d['data'])                #in some of dict len(dict) is not equal so for this it is not able to convert into dataframe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-13f6de2da64a> in <module>
# ----> 1 pd.DataFrame(d['data'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
#try to remove some dict value having null values

# %%
del d1['diagnosticTroubleCodeData']

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
 url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json() #it will convert data into raw json formate

# %%
data1  # from all the data from internet we are able to get it
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46241',
#   'id': 1160431554,
#   'node_id': 'PR_kwDOAA0YD84z_ppo',
#   'number': 46241,
#   'title': 'CI/TYP: pyright reportSelfClsParameterName',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
# ...

# %%
len(data1)
# Out:
# 30

# %%
data1[0]          #it will fetch only one dictionary
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/46241',
#  'id': 1160431554,
#  'node_id': 'PR_kwDOAA0YD84z_ppo',
#  'number': 46241,
#  'title': 'CI/TYP: pyright reportSelfClsParameterName',
#  'user': {'login': 'twoertwein',
#   'id': 6618166,
#   'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/twoertwein',
#   'html_url': 'https://github.com/twoertwein',
#   'followers_url': 'https://api.github.com/users/twoertwein/followers',
# ...

# %%
data1[0]['user'] # im able to show all the users here
# Out:
# {'login': 'twoertwein',
#  'id': 6618166,
#  'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/twoertwein',
#  'html_url': 'https://github.com/twoertwein',
#  'followers_url': 'https://api.github.com/users/twoertwein/followers',
#  'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#  'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#  'repos_url': 'https://api.github.com/users/twoertwein/repos',
#  'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#  'type': 'User',
# ...

# %%
data1[0]['user']['id']        #im extract one songle id
# Out:
# 6618166

# %%
#all these 30 row i want user id

# %%
for i in range(len(data1)):                
    print(data1[0]['user']['id'])
# Out:
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166
# 6618166

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46241/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46241',
#   'id': 1160431554,
#   'node_id': 'PR_kwDOAA0YD84z_ppo',
#   'number': 46241,
#   'title': 'CI/TYP: pyright reportSelfClsParameterName',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
# ...

# %%
#fetch all url(commit_url,lebel_url...like that)

# %%
pd.DataFrame(data1, columns=['url','repository_url','lebels_url']) # it will show column wise data
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(data1, columns=['id', 'url','repository_url','lebels_url'])
# Out:
#             id                                                url  \
# 0   1160431554  https://api.github.com/repos/pandas-dev/pandas...
# 1   1160431471  https://api.github.com/repos/pandas-dev/pandas...
# 2   1160393154  https://api.github.com/repos/pandas-dev/pandas...
# 3   1160389512  https://api.github.com/repos/pandas-dev/pandas...
# 4   1160198674  https://api.github.com/repos/pandas-dev/pandas...
# 5   1160089928  https://api.github.com/repos/pandas-dev/pandas...
# 6   1160064471  https://api.github.com/repos/pandas-dev/pandas...
# 7   1159934807  https://api.github.com/repos/pandas-dev/pandas...
# 8   1159874789  https://api.github.com/repos/pandas-dev/pandas...
# 9   1159791857  https://api.github.com/repos/pandas-dev/pandas...
# 10  1159657724  https://api.github.com/repos/pandas-dev/pandas...
# 11  1159602954  https://api.github.com/repos/pandas-dev/pandas...
# 12  1159567404  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(data1, columns=['id', 'url','repository_url','lebels_url','user'])
# Out:
#             id                                                url  \
# 0   1160431554  https://api.github.com/repos/pandas-dev/pandas...
# 1   1160431471  https://api.github.com/repos/pandas-dev/pandas...
# 2   1160393154  https://api.github.com/repos/pandas-dev/pandas...
# 3   1160389512  https://api.github.com/repos/pandas-dev/pandas...
# 4   1160198674  https://api.github.com/repos/pandas-dev/pandas...
# 5   1160089928  https://api.github.com/repos/pandas-dev/pandas...
# 6   1160064471  https://api.github.com/repos/pandas-dev/pandas...
# 7   1159934807  https://api.github.com/repos/pandas-dev/pandas...
# 8   1159874789  https://api.github.com/repos/pandas-dev/pandas...
# 9   1159791857  https://api.github.com/repos/pandas-dev/pandas...
# 10  1159657724  https://api.github.com/repos/pandas-dev/pandas...
# 11  1159602954  https://api.github.com/repos/pandas-dev/pandas...
# 12  1159567404  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df2 = pd.DataFrame(data1, columns=['id', 'url','repository_url','lebels_url','user'])

# %%
df2.to_csv('json_res.csv') # create file in c drive just check it

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is DE5C-05B8
#
#  Directory of C:\Users\Nplite\Favorites
#
# 06-03-2022  02:51    <DIR>          .
# 05-03-2022  22:51    <DIR>          ..
# 06-03-2022  01:43    <DIR>          .ipynb_checkpoints
# 19-02-2022  23:01    <DIR>          __pycache__
# 08-02-2022  06:47           144,486 1.Basic, List, Tuple, Dictionary  ===1.ipynb
# 21-02-2022  12:54            79,738 2.If Else, Range, For, While.ipynb
# 22-02-2022  00:08            75,849 3. Function, Lambda,Generator.ipynb
# 22-02-2022  17:53           105,786 4.Generator, Fibonacci no, Open,Write,Read file.ipynb
# 24-02-2022  20:36            79,714 5.Exception Handling, Logging.ipynb
# 28-02-2022  01:20           117,642 6.Class.ipynb
# 05-03-2022  18:08             1,173 addresses.csv
# 23-02-2022  23:20            19,704 ADVANCE TASK INEURON.ipynb
# 05-03-2022  13:07             1,503 CASSANDRA.ipynb
# 05-03-2022  18:08             1,589 contacts.csv
# ...

# %%
05/03/2022      pandas day3 class

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes      # try to fetch datatype of all elements
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe() #by default it will consider in just numeric columb itself it not going to consider categorical
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#min,25%,50%,75%,max will shows the indexes of data not a percentage of data
# read a data and understand it.... mean of passengerid it imp its illogical so check such variables and take a action on them

# %%
df.columns        #this function will only consider the datatype = int
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#try to descibe the function which shows the datatype = object(str)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == "object"       # it will show which one is object(str)
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == "object"].index      # it will extract those object which data type is object or str
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name = df.dtypes[df.dtypes == "object"].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[col_name].describe()    #small dicsription of data it is helpfull for us
# Out:
#                                 Name   Sex    Ticket        Cabin Embarked
# count                            891   891       891          204      889
# unique                           891     2       681          147        3
# top     Hoyt, Mr. Frederick Maxfield  male  CA. 2343  C23 C25 C27        S
# freq                               1   577         7            4      644

# %%
df           #try to add a new column to this dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['ineuron'] = "sudh"   #it will add ew column name ineuron and values is sudh

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#try to give me first fifteen record without using head function

# %%
df['Name'][0:15]  # just like a list slicing operation
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][::-1] #reverse record
# Out:
# 890                                  Dooley, Mr. Patrick
# 889                                Behr, Mr. Karl Howell
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 887                         Graham, Miss. Margaret Edith
# 886                                Montvila, Rev. Juozas
#                              ...
# 4                               Allen, Mr. William Henry
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                                 Heikkinen, Miss. Laina
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 0                                Braund, Mr. Owen Harris
# Name: Name, Length: 891, dtype: object

# %%
#try to extract null values

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age'].isnull() ==  True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
#try to give me indexes

# %%
df[df['Age'].isnull() ==  True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
# how many place we have null values

# %%
len(df[df['Age'].isnull() ==  True].index)
# Out:
# 177

# %%
ind = df[df['Age'].isnull() ==  True].index

# %%
df.loc[ind]    # it will show all the records where we have age is null
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#try to extract a person name who has paid highest fair

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare'] == max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     ineuron
# 258    sudh
# 679    sudh
# 737    sudh

# %%
df[df['Fare'] == max(df['Fare'])]['Name'] # it will shows name of that three persons whose paid fare is highest
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
 df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     ineuron
# 258    sudh
# 679    sudh
# 737    sudh

# %%
import pandas as pd

# %%
"""
1.findout how many male and female passenger was onboarded
2.how many survived we have
3.how many casualty we have
4. what is name of a person who is eldst one
5. how many passenger do we have in first secod and third class
6. how many persons we have whose name strating with 's'
7. try to create new column whic is summation of 'SibSp' and 'parch' 
8. how many person do we have bellow age of 25
9. how many persons have died whose age was less than 40
10.from a cabin column seprate text and numeric values"""
# Out:
# "\n1.findout how many male and female passenger was onboarded\n2.how many survived we have\n3.how many casualty we have\n4. what is name of a person who is eldst one\n5. how many passenger do we have in first secod and third class\n6. how many persons we have whose name strating with 's'\n7. try to create new column whic is summation of 'SibSp' and 'parch' \n8. how many person do we have bellow age of 25\n9. how many persons have died whose age was less than 40\n10.from a cabin column seprate text and numeric values"

# %%
pd.read_csv('D:\\INEURON\\h\\bank\\bank.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-83aa20cbdbad> in <module>
# ----> 1 pd.read_csv('D:\\INEURON\\h\\bank\\bank.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
pd.read_csv('D:\\INEURON\\h\\bank\\bank.csv', sep = ";")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
1. how many campaign available in this dataset
2. how many users do we have with housing and personal loan
3. how many person do we have whhose age is 60+
4. in which month we have targeted most of the customer
5. which mode of call is giving you more result
6. how many enterpreners de we have in this list
7. how many customers do we have with negative balance
8. preapre a group of data based on education level
9.
