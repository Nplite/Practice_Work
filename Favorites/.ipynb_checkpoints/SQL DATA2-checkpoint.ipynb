# %%
# !pip install mysql-connector-python   #driver for communication btwn jupytor and mysql
# Out:
# ERROR: Invalid requirement: '#driver'

# %%
import mysql.connector as conn          #import a library

# %%
mydb = conn.connect(host = "localhost", user = "root", passwd = "Ns.np#123" )      #make a connection

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('cardataset1',),
#  ('information_schema',),
#  ('mysql',),
#  ('namdeo',),
#  ('namdeo1',),
#  ('performance_schema',),
#  ('sys',),
#  ('testsudh',),
#  ('testsudhineuron',),
#  ('testsudhineuron1',),
#  ('testsudhineuron11',),
#  ('testsudhineuron121',)]

# %%
cursor = mydb.cursor()

# %%
cursor.execute("create database namdeo1")

# %%
cursor.execute("create table namdeo1.patil(studentid INT(10), firstname VARCHAR(30), lastname VARCHAR(30), regid INT(10), classname VARCHAR(30))")

# %%
cursor.execute("show tables")

# %%
cursor.execute("use namdeo1")

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()

# %%
cursor.execute("insert into namdeo1.patil values(12345, 'sudh', 'kumar', 987654, 'ineuron')") # do not use double quote("") for defining str

# %%
mydb.commit()   #unless and untill you are not going to commit the data you will not be able to see a data at mysql notebook

# %%
# same data we are looking inside a jupytor notebook

# %%
cursor.execute(" select * from namdeo1.patil")

# %%
cursor.fetchall()

# %%
cursor.execute("insert into namdeo1.patil values(123456, 'sudhhanshu', 'Rajkumar', 9876543, 'ineuron12')") # in this way we can add or store multiple data inside the any collomb at any time

# %%
mydb.commit()

# %%
cursor.execute("select * from namdeo1.patil")

# %%
cursor.fetchall()

# %%
cursor.execute("insert into namdeo1.patil values(123456, 'anshu', 'Raj', 987, 'ron12')")

# %%
mydb.commit()

# %%
cursor.execute("select * from namdeo1.patil")

# %%
cursor.fetchall()

# %%
cursor.execute('create table namdeo1.glassdata(col1 INT(10), col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 INT(10))')

# %%
"create table namdeo1.patil.glass.data(col1 INT(10), col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 INT(10)"

# %%
cursor.execute("use namdeo")

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()

# %%
file = open("glass.data", "r+")

# %%
file.read()

# %%
import csv

# %%
with open("glass.data","r") as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for i in glass_data:  #reading data in sequential line formate
        print(i)

# %%
cursor.execute('create table namdeo.glassdata(col1 INT(10), col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 INT(10))')

# %%
#insert a one single record

# %%
cursor.execute("insert into namdeo1.glassdata values('1,1.51,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1')")

# %%
"insert into namdeo1.glassdata values(['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']"

# %%
mydb.commit()

# %%
cursor.execute("select * from namdeo1.glassdata")

# %%
cursor.fetchall()

# %%
#fetch all record of glassdata one by one

# %%
with open('glass.data', "r") as f:
    glass_data = csv.reader(f,delimiter = '\n')
    for i in glass_data:
        print(i)
        print(f'insert into glassdata values ({str(i[0])})')
        cursor.execute(f'insert into namdeo1.glassdata values ({str(i[0])})')

# %%
mydb.commit()

# %%
cursor.execute("select * from namdeo1.glassdata")

# %%
cursor.fetchall()

# %%
with open('glass.data', "r") as f:
    glass_data = csv.reader(f,delimiter = '\n')                    # this is another method to access a data
    for i in glass_data:
        print(i)
        print(f'insert into glassdata values ({str(i[0])})')
        cursor.execute('insert into namdeo1.glassdata values({values})'.format(values = ((i[0]))))

# %%
mydb.commit()

# %%
import pandas as pd

# %%
#all this operation done with the help of pandas also even this is possible

# %%
pd.read_sql("select * from namdeo1.glassdata", mydb)

# %%
pd.read_sql("show databases",mydb)

# %%
# 06/02/2022

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = "localhost", user = "root", passwd = "Ns.np#123")

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()

# %%
cursor.execute("select * from namdeo1.glassdata")

# %%
cursor.fetchall()

# %%
cursor.execute("select * from namdeo1.patil")  # select * == select coloumb from this file

# %%
cursor.fetchall()

# %%
cursor.execute("select col1, col5, col10 from namdeo1.glassdata")

# %%
cursor.fetchall()

# %%
cursor.execute("select col1, col5, col5, col10 from namdeo1.glassdata")

# %%
cursor.fetchall()

# %%
 cursor.execute("select * from  namdeo1.glassdata WHERE col1= 4 ")

# %%
cursor.fetchall()

# %%
 cursor.execute("select * from  namdeo1.glassdata WHERE col1= 4  and col11 = 1")

# %%
cursor.fetchall()

# %%
 cursor.execute("select * from  namdeo1.glassdata WHERE col1= 4  and col11 = 0") # if there is no value exist then it will shown black list

# %%
cursor.fetchall()

# %%
cursor.execute("delete from namdeo1.glassdata WHERE col1=4")

# %%
mydb.commit()

# %%
 cursor.execute("select * from  namdeo1.glassdata ")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 8.0, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("update namdeo1.glassdata SET col1 = 6, col2 = 8 where col1 = 5")

# %%
cursor.execute("update namdeo1.glassdata SET col1 = 6, col2 = 8 where col1 = 1")

# %%
mydb.commit()

# %%
cursor.execute("select * from namdeo1.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 8.0, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from namdeo1.glassdata where col1 = 6 ")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
cursor.execute("select count(col1) from namdeo1.glassdata group by col1 ")

# %%
cursor.fetchall()
# Out:
# [(6,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
#  (2,),
# ...

# %%
cursor.execute("select count(col1),col2 from namdeo1.glassdata group by col1 ")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0),
#  (2, 1.51761),
#  (2, 1.51618),
#  (2, 1.51743),
#  (2, 1.51756),
#  (2, 1.51918),
#  (2, 1.51755),
#  (2, 1.51571),
#  (2, 1.51763),
#  (2, 1.51589),
#  (2, 1.51748),
#  (2, 1.51763),
#  (2, 1.51761),
#  (2, 1.51784),
#  (2, 1.52196),
#  (2, 1.51911),
#  (2, 1.51735),
#  (2, 1.5175),
#  (2, 1.51966),
#  (2, 1.51736),
#  (2, 1.51751),
#  (2, 1.5172),
#  (2, 1.51764),
#  (2, 1.51793),
#  (2, 1.51721),
#  (2, 1.51768),
#  (2, 1.51784),
#  (2, 1.51768),
#  (2, 1.51747),
#  (2, 1.51775),
#  (2, 1.51753),
#  (2, 1.51783),
#  (2, 1.51567),
#  (2, 1.51909),
#  (2, 1.51797),
#  (2, 1.52213),
#  (2, 1.52213),
#  (2, 1.51793),
#  (2, 1.51755),
#  (2, 1.51779),
#  (2, 1.5221),
#  (2, 1.51786),
#  (2, 1.519),
#  (2, 1.51869),
#  (2, 1.52667),
#  (2, 1.52223),
#  (2, 1.51898),
#  (2, 1.5232),
#  (2, 1.51926),
#  (2, 1.51808),
#  (2, 1.51837),
#  (2, 1.51778),
#  (2, 1.51769),
#  (2, 1.51215),
#  (2, 1.51824),
#  (2, 1.51754),
#  (2, 1.51754),
#  (2, 1.51905),
#  (2, 1.51977),
# ...

# %%
cursor.execute("select col1, count(col1), col2, col5, col7 from namdeo1.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 426, 8.0, 1.1, 0.06)]

# %%
cursor.execute("select col1, count(col1), col2, col5, col7 from namdeo1.glassdata group by col1")

# %%
cursor.fetchall()
# Out:
# [(6, 6, 8.0, 1.1, 0.06),
#  (2, 2, 1.51761, 1.36, 0.48),
#  (3, 2, 1.51618, 1.54, 0.39),
#  (7, 2, 1.51743, 1.14, 0.58),
#  (8, 2, 1.51756, 1.05, 0.57),
#  (9, 2, 1.51918, 1.37, 0.56),
#  (10, 2, 1.51755, 1.36, 0.57),
#  (11, 2, 1.51571, 1.56, 0.67),
#  (12, 2, 1.51763, 1.27, 0.6),
#  (13, 2, 1.51589, 1.4, 0.69),
#  (14, 2, 1.51748, 1.27, 0.54),
#  (15, 2, 1.51763, 1.31, 0.58),
#  (16, 2, 1.51761, 1.23, 0.58),
#  (17, 2, 1.51784, 1.16, 0.61),
#  (18, 2, 1.52196, 0.89, 0.15),
#  (19, 2, 1.51911, 1.18, 0.06),
#  (20, 2, 1.51735, 1.69, 0.54),
#  (21, 2, 1.5175, 1.49, 0.54),
#  (22, 2, 1.51966, 0.29, 0.03),
#  (23, 2, 1.51736, 1.29, 0.59),
#  (24, 2, 1.51751, 1.35, 0.62),
#  (25, 2, 1.5172, 1.15, 0.5),
#  (26, 2, 1.51764, 1.21, 0.65),
#  (27, 2, 1.51793, 1.41, 0.59),
#  (28, 2, 1.51721, 1.33, 0.56),
#  (29, 2, 1.51768, 1.43, 0.57),
#  (30, 2, 1.51784, 1.28, 0.6),
#  (31, 2, 1.51768, 1.3, 0.61),
#  (32, 2, 1.51747, 1.14, 0.56),
#  (33, 2, 1.51775, 1.23, 0.61),
# ...

# %%
cursor.execute("select * from namdeo1.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 8.0, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
#how many time 2 appear hoe many times 6 appears

# %%
cursor.execute("select * from namdeo1.glassdata where col1 = 26 ")

# %%
cursor.fetchall()  # col =26 apears only two times
# Out:
# [(26, 1.51764, 12.98, 3.54, 1.21, 73.0, 0.65, 8.53, 0.0, 0.0, 1),
#  (26, 1.51764, 12.98, 3.54, 1.21, 73.0, 0.65, 8.53, 0.0, 0.0, 1)]

# %%
cursor.execute("select * from namdeo.patil")

# %%
cursor.fetchall()   # how many times FSDS appears count it
# Out:
# [(12345, 'sudh', 'kumar', 987654, 'ineuron'),
#  (12345, 'sudh', 'kumar', 987654, 'ineuron'),
#  (123456, 'sudhhanshu', 'Rajkumar', 9876543, 'ineuron12'),
#  (123456, 'sudhhanshu', 'Rajkumar', 9876543, 'ineuron12'),
#  (123456, 'anshu', 'Raj', 987, 'ron12'),
#  (123456, 'sudhhanshu', 'Rajkumar', 9876543, 'ineuron12'),
#  (123456, 'anshu', 'Raj', 987, 'ron12'),
#  (123456, 'anshu', 'Raj', 987, 'ron12'),
#  (12345, 'sudh', 'kumar', 987654, 'ineuron')]

# %%
cursor.execute("select count(*) from namdeo.patil where classname = 'ineuron'")

# %%
cursor.fetchall()
# Out:
# [(3,)]

# %%
cursor.execute("select count(classname), classname from namdeo.patil where classname = 'ineuron'")

# %%
cursor.fetchall()
# Out:
# [(3, 'ineuron')]

# %%
cursor.execute("select count(lastname), lastname from namdeo.patil where lastname = 'Rajkumar'")

# %%
cursor.fetchall()
# Out:
# [(3, 'Rajkumar')]

# %%
cursor.execute("select count(*) , classname from namdeo.patil group by classname")

# %%
cursor.fetchall()
# Out:
# [(3, 'ineuron'), (3, 'ineuron12'), (3, 'ron12')]

# %%
cursor.execute("select count(*) , studentid from namdeo.patil group by studentid")

# %%
cursor.fetchall()
# Out:
# [(3, 12345), (6, 123456)]

# %%
cursor.execute("select count(*), studentid from namdeo.patil where studentid = '123456'")

# %%
#group by consider all the occurances and where clouse consider a only condition that we are given
# Both are completly different
